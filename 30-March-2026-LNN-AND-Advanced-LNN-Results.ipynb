# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/ATGLNets/blob/fix-threshold-lnn-advanced-lnn/30-March-2026-LNN-AND-Advanced-LNN-Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

destination_dir = 'ATGLNets/preprocessed_datasets/ukdale'
if not os.path.exists(destination_dir):
    os.makedirs(destination_dir)
    print(f"Created directory: {destination_dir}")
else:
    print(f"Directory already exists: {destination_dir}")
# Out:
# Created directory: ATGLNets/preprocessed_datasets/ukdale

# %%
source_path = '/content/drive/MyDrive/ukdale.h5'
destination_path = 'ATGLNets/preprocessed_datasets/ukdale/ukdale.h5'

# !mv "{source_path}" "{destination_path}"

print(f"Moved {source_path} to {destination_path}")
# Out:
# Moved /content/drive/MyDrive/ukdale.h5 to ATGLNets/preprocessed_datasets/ukdale/ukdale.h5

# %%
import os

# Store the original working directory to restore it later
original_cwd = os.getcwd()

# Change directory to ATGLNets
os.chdir('ATGLNets')

# Run the data_loader.py script
# The script will now look for 'preprocessed_datasets/ukdale/ukdale.h5'
# relative to ATGLNets, which is the correct path:
# /content/ATGLNets/preprocessed_datasets/ukdale/ukdale.h5
# !python data_loader.py

# Change back to the original working directory
os.chdir(original_cwd)
# Out:
# Exploring: preprocessed_datasets/ukdale/ukdale.h5
#
#   House 1: ['meter1', 'meter10', 'meter11', 'meter12', 'meter13', 'meter14', 'meter15', 'meter16', 'meter17', 'meter18', 'meter19', 'meter2', 'meter20', 'meter21', 'meter22', 'meter23', 'meter24', 'meter25', 'meter26', 'meter27', 'meter28', 'meter29', 'meter3', 'meter30', 'meter31', 'meter32', 'meter33', 'meter34', 'meter35', 'meter36', 'meter37', 'meter38', 'meter39', 'meter4', 'meter40', 'meter41', 'meter42', 'meter43', 'meter44', 'meter45', 'meter46', 'meter47', 'meter48', 'meter49', 'meter5', 'meter50', 'meter51', 'meter52', 'meter53', 'meter54', 'meter6', 'meter7', 'meter8', 'meter9']
#   House 2: ['meter1', 'meter10', 'meter11', 'meter12', 'meter13', 'meter14', 'meter15', 'meter16', 'meter17', 'meter18', 'meter19', 'meter2', 'meter20', 'meter3', 'meter4', 'meter5', 'meter6', 'meter7', 'meter8', 'meter9']
# ...

# %%
import os

original_cwd = os.getcwd()
os.chdir('ATGLNets')

# !python train_lnn.py

os.chdir(original_cwd)
# Out:
# Training LNN for 5 appliances in house 2:
#   0: fridge
#   1: dishwasher
#   2: microwave
#   3: washer_dryer
#   4: kettle
#
# Pre-loading house data...
#
# === House 2 ===
#   Mains: 2780373 samples  (2013-02-17 16:17:34+00:00 -> 2013-10-10 05:15:50+00:00)
#   [FOUND] 'fridge' at meter 4: 2801065 samples
#     train: 102745 samples (expected 14400, 2013-04-10)
#     val: 14399 samples (expected 14400, 2013-07-08)
#     test: 14399 samples (expected 14400, 2013-10-09)
#     train_loader: (20529, 100, 1)
#     val_loader: (2860, 100, 1)
#     test_loader: (2860, 100, 1)
#   [FOUND] 'dishwasher' at meter 3: 2805646 samples
#     train: 102745 samples (expected 14400, 2013-04-10)
#     val: 14399 samples (expected 14400, 2013-07-08)
#     test: 14399 samples (expected 14400, 2013-10-09)
#     train_loader: (20529, 100, 1)
#     val_loader: (2860, 100, 1)
#     test_loader: (2860, 100, 1)
#   [FOUND] 'microwave' at meter 5: 2806036 samples
# ...

# %%
import os

original_cwd = os.getcwd()
os.chdir('ATGLNets')

# !python train_advanced_lnn.py

os.chdir(original_cwd)
# Out:
# Training Advanced LNN for 5 appliances in house 2:
#   0: fridge
#   1: dishwasher
#   2: microwave
#   3: washer_dryer
#   4: kettle
#
# Pre-loading house data...
#
# === House 2 ===
#   Mains: 2780373 samples  (2013-02-17 16:17:34+00:00 -> 2013-10-10 05:15:50+00:00)
#   [FOUND] 'fridge' at meter 4: 2801065 samples
#     train: 102745 samples (expected 14400, 2013-04-10)
#     val: 14399 samples (expected 14400, 2013-07-08)
#     test: 14399 samples (expected 14400, 2013-10-09)
#     train_loader: (20529, 100, 1)
#     val_loader: (2860, 100, 1)
#     test_loader: (2860, 100, 1)
#   [FOUND] 'dishwasher' at meter 3: 2805646 samples
#     train: 102745 samples (expected 14400, 2013-04-10)
#     val: 14399 samples (expected 14400, 2013-07-08)
#     test: 14399 samples (expected 14400, 2013-10-09)
#     train_loader: (20529, 100, 1)
#     val_loader: (2860, 100, 1)
#     test_loader: (2860, 100, 1)
#   [FOUND] 'microwave' at meter 5: 2806036 samples
# ...
