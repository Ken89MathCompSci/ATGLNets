# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/ATGLNets/blob/fix-threshold-lnn-advanced-lnn/11-April-2026-Basic-lnn-inter-layer-UKdale-dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_lnn_ukdale_specific_splits.py
# Out:
# Testing LiquidNetworkModel on UKDALE dataset with specific splits...
# Loading UKDALE data with specific splits...
# Train data shape: (14400, 5)
# Validation data shape: (14400, 5)
# Test data shape: (14400, 5)
# Train date range: 2014-11-09 00:00:00 to 2014-11-09 23:59:54
# Val   date range: 2014-12-07 00:00:00 to 2014-12-07 23:59:54
# Test  date range: 2014-08-24 00:00:00 to 2014-08-24 23:59:54
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Testing LiquidNetworkModel on dish washer
# ...
#
# Using device: cuda
# Creating sequences for dish washer...
# Training sequences:   (2861, 100, 1) -> (2861, 1)
# Validation sequences: (2861, 100, 1) -> (2861, 1)
# Test sequences:       (2861, 100, 1) -> (2861, 1)
# Starting LiquidNetworkModel training for dish washer...
# Epoch 1/80: 100% 90/90 [00:07<00:00, 12.06it/s, loss=0.000396]
# ...
